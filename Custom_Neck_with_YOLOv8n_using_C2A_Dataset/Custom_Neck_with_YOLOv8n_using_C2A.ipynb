# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 51.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 8.3.32

# %%
# !pip install --upgrade ultralytics

# %%
from ultralytics.models import yolo
print(dir(yolo))
# Out:
# ['YOLO', 'YOLOWorld', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'classify', 'detect', 'model', 'obb', 'pose', 'segment', 'world']

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Load the YOLOv8 model (from YAML or pretrained weights)
model = YOLO("yolov8n.yaml")  # Alternatively, "yolov8n.pt" for pretrained weights

# Inspect the model architecture
print(model.model)
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
import torch.nn as nn

# Define a custom neck with additional layers (e.g., FPN)
class CustomNeck(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(256, 128, kernel_size=1)
        self.conv2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)

    def forward(self, x):
        # Example forward pass
        x = self.conv1(x)
        x = self.conv2(x)
        return x

# Replace or extend the neck in the YOLO model
model.model.neck = CustomNeck()

# Verify the updated model structure
print(model.model)
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
# !unzip /content/drive/MyDrive/Data.zip -d /content/Data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0188_4.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0189_0.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0189_1.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0189_2.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0189_3.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0189_4.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0190_0.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0190_3.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0191_0.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0191_1.txt
#   inflating: /content/Data/Data/train/labels/traffic_incident_image0191_2.txt
# ...

# %%
# Train the model on your dataset
results = model.train(data="/content/Data/data.yaml", epochs=3, imgsz=320)
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
import os

# Define source and destination paths
source = "/content/runs/detect/train"
destination = "/content/drive/MyDrive/YoloProject/runs/train_custom"

# Remove the existing directory if it exists
if os.path.exists(destination):
    shutil.rmtree(destination)

# Copy the directory
shutil.copytree(source, destination)
# Out:
# '/content/drive/MyDrive/YoloProject/runs/train_custom'
